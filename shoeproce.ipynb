# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data.csv")
#Show the first 15 contents
df
# Out:
#          brand        color size  price  offer_price
# 0     Tresmode        Black  6.5   4647         4153
# 1        Lavie         Gold    4   2446         1172
# 2         FILA          Red    6   2346         1898
# 3        Crocs          Red    5   5942         5868
# 4        Crocs         Blue    4   2942         2118
# ...        ...          ...  ...    ...          ...
# 5674      Toms  Red & White    4   6747         5098
# 5675     Crocs        Black    7   2942         2868
# 5676      Toms         Blue    9   4847         3673
# 5677   Liberty        Black    6   2146         1722
# 5678     Crocs        Brown    2   3442         3368
#
# [5679 rows x 5 columns]

# %%
#Shape of dataset
df.shape
# Out:
# (5679, 5)

# %%
#Columns of dataset
df.columns
# Out:
# Index(['brand', 'color', 'size', 'price', 'offer_price'], dtype='object')

# %%
#Dataframe summary 
def summary(df):
    print(f'data shape: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['Data Type'])
    summ['Missing#'] = df.isna().sum()
    summ['Missing%'] = (df.isna().sum())/len(df)
    summ['Dups'] = df.duplicated().sum()
    summ['Uniques'] = df.nunique().values
    summ['Count'] = df.count().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['Min'] = desc['min'].values
    summ['Max'] = desc['max'].values
    summ['Average'] = desc['mean'].values
    summ['Standard Deviation'] = desc['std'].values
    summ['First Value'] = df.loc[0].values
    summ['Second Value'] = df.loc[1].values
    summ['Third Value'] = df.loc[2].values

    display(summ)

summary(df)

#There are duplicate of the same shoe brand with same size
# Out:
# data shape: (5679, 5)
#             Data Type  Missing#  Missing%  Dups  Uniques  Count     Min  \
# brand          object         0       0.0  1042       30   5679     NaN
# color          object         0       0.0  1042      115   5679     NaN
# size           object         0       0.0  1042       38   5679     NaN
# price           int64         0       0.0  1042      178   5679  1346.0
# offer_price     int64         0       0.0  1042      386   5679   773.0
#
#                  Max      Average Standard Deviation First Value Second Value  \
# brand            NaN          NaN                NaN    Tresmode        Lavie
# color            NaN          NaN                NaN       Black         Gold
# size             NaN          NaN                NaN         6.5            4
# price        37947.0  4945.126255        5344.881308        4647         2446
# offer_price  34123.0  4007.745026        4761.543884        4153         1172
#
#             Third Value
# ...

# %%
#Delete duplicate
df = df.drop_duplicates()

# %%
# Highest Shoes according to Price
df.sort_values(["price"], axis=0, ascending=False, inplace=True)
df.head(10)
# Out:
#            brand      color  size  price  offer_price
# 3315  Tory Burch     Orange   5.5  37947        34123
# 1700  Tory Burch       Navy    11  37947        34123
# 4618  Tory Burch       Navy     8  37947        34123
# 2573  Tory Burch  Off White     6  37947        34123
# 2637  Tory Burch     Orange     6  37947        34123
# 1822  Tory Burch     Orange   9.5  37947        34123
# 3238  Tory Burch       Navy   7.5  37947        34123
# 4712  Tory Burch  Off White  10.5  37947        34123
# 2142  Tory Burch  Off White     9  37947        34123
# 2698  Tory Burch     Orange     9  37947        34123

# %%
# Group by 'color' and find the maximum price for each color
color_max_price = df.groupby('color')['price'].max()

# Plotting the graph
plt.figure(figsize=(10, 6))
color_max_price.sort_values(ascending=False).plot(kind='bar', color='skyblue')

# Adding titles and labels
plt.title('Highest Price of Shoes by Color', fontsize=14)
plt.xlabel('Color', fontsize=12)
plt.ylabel('Highest Price', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by 'size' and find the maximum price for each size
size_max_price = df.groupby('size')['price'].max()

# Plotting the graph
plt.figure(figsize=(10, 6))
size_max_price.sort_values(ascending=False).plot(kind='bar', color='lightgreen')

# Adding titles and labels
plt.title('Highest Price of Shoes by Size', fontsize=14)
plt.xlabel('Size', fontsize=12)
plt.ylabel('Highest Price', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by 'brand' and find the average price for each brand
brand_avg_price = df.groupby('brand')['price'].mean()

# Plotting the graph
plt.figure(figsize=(12, 6))
brand_avg_price.sort_values(ascending=False).plot(kind='bar', color='lightcoral')

# Adding titles and labels
plt.title('Average Price of Shoes by Brand', fontsize=14)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Average Price', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by 'brand' and find the maximum price for each brand
brand_max_price = df.groupby('brand')['price'].max()

# Plotting the graph
plt.figure(figsize=(12, 6))
brand_max_price.sort_values(ascending=False).plot(kind='bar', color='lightgreen')

# Adding titles and labels
plt.title('Maximum Price of Shoes by Brand', fontsize=14)
plt.xlabel('Brand', fontsize=12)
plt.ylabel('Maximum Price', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
